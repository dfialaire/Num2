# %% [markdown]
# <div style="text-align:center; border:2px solid black; font-size: 1.8em;">
# <h1>DS  : Récursivité N°2</h1>
#     <br>
# </div>

# %% [markdown]
# # <span style="color:red"> <u>Inscrivez votre Prénom ici</u> :

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:DodgerBlue;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid DarkBlue;margin:0px 10px 10px 10px;padding:10px;">
# <h4><u>Exercice 1</u> : </h4>
#     <br>Ecrire une fonction <u>récursive</u> <b>binaire(n)</b> qui donnera comme résultat la concaténation à l'envers des restes des divisions successives de n par 2 (n étant un entier positif).
# <br><br>
# <u>Exemple</u> : </br>
#
# ~~~ Python
# binaire(11)  # soit 11/2=5 --> 1 ; 5/2=2 --> 1 ; 2/2=1 -->0 ; 1/2=0 --> 1..  Donc '1011'
# >> 1011
#
# ~~~
#
# <br>
# <u>Rappel:</u><br>
#
# ~~~ Python
# 11//2
# >> 5
#
# 11%2
# >> 1
#
# ~~~
# <br>
# <u>Stratégie:</u><br><br>
# Pour concaténer à l'envers les restes successifs de division par 2, vous pouvez renvoyer, récursivement :
# <br><br>
# <br>
# <ul><ul>quelque_chose + chaine<br><br>
#     </ul></ul>où chaine est votre résutat en cours de construction...<br>
# Comme chaine se trouve à la fin de votre concaténation, les restes seront concaténer de manière inversée.

# %%
def binaire(n):
    # écrivez le code la la fonction ici



# zone de test : pas toucher !
assert binaire(11) == '1011', "⛔️ Erreur test 1 ! Essaye encore ! ⛔️"

print("👏 BRAVO ! 👏")
# Out:
# 👏 BRAVO ! 👏

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:DodgerBlue;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid DarkBlue;margin:0px 10px 10px 10px;padding:10px;">
# <h4><u>Exercice 2</u> : </h4>
#     <br>Ecrire une fonction <u>récursive</u> <b>decodage(texte, cle)</b> qui renvoie le texte décodé grace à une clé de déchiffrement :<br><br>
# ==> Une clé = 2 ne gardera que les caractères d'indice 0, 2, 4, 6...<br><br>
# ==> Une clé = 3 ne gardera que les caractères d'indice 0, 3, 6, 9...<br><br>
# <u>Exemples</u> : </br>
#
# ~~~ Python
# texte = "sghujupsderfrfr,bn xwesqtsz frtghojuiku ki?po"
# decodage(texte, 3)
#
# >> "super, et toi ?"
#
# ~~~
#
# <b><u>Ps</u></b> : <i>Vous pouvez utiliser le sliding.

# %%
def decodage(texte, cle): 
    # écrivez le code la la fonction ici



# zone de test : pas toucher !
texte = "Biounsjgonucrt,t gcyojmkmserngth jckao lvyaf h?"
assert decodage(texte, 2)  == "Bonjour, comment ca va ?", "⛔️ Erreur test 1 ! Essaye encore ! ⛔️"
texte = "sghujupsderfrfr,bn xwesqtsz frtghojuiku ki?po"
assert decodage(texte, 3)  == "super, et toi ?", "⛔️ Erreur test 2 ! Essaye encore ! ⛔️"

print("👏 BRAVO ! 👏")
# Out:
# 👏 BRAVO ! 👏

# %% [markdown]
# <div style="text-align:center; border:0px ;background-color:DodgerBlue;margin:10px 10px 0px 10px;padding:10px;">
#     </div>
# <div style="border:2px solid DarkBlue;margin:0px 10px 10px 10px;padding:10px;">
# <h4><u>Exercice 3</u> : </h4>
#     <br>Ecrire une fonction <u>récursive</u> <b>inverse_liste(Liste)</b> qui renvoie <u>une nouvelle liste</u> correspondant excatement à l'inverse de la première.</br></br>
#     <u>Exemples</u> : </br>
#
# ~~~ Python
# Liste = [2, 4, 6, 8, 10]
# inverse_liste(Liste)
# >> [10, 8, 6, 4, 2]
#
# Liste = [1]
# inverse_liste(Liste)
# >> [1]
#
# Liste = []
# inverse_liste(Liste)
# >> []
#
# ~~~
#
# <b><u>Ps</u></b> : <i>Vous pouvez utiliser le sliding.

# %%
def inverse_liste(Liste) : 
    # écrivez le code la la fonction ici
    

    
# zone de test : pas toucher !
Liste = [2, 4, 6, 8, 10]
assert inverse_liste(Liste)  == [10, 8, 6, 4, 2], "⛔️ Erreur test 1 ! Essaye encore ! ⛔️"
Liste = [1]
assert inverse_liste(Liste)  == [1], "⛔️ Erreur test 2 ! Essaye encore ! ⛔️"
Liste = []
assert inverse_liste(Liste)  == [], "⛔️ Erreur test 3 ! Essaye encore ! ⛔️"

print("👏 BRAVO ! 👏")
